# %%
#IMPORTING LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")

# %%
#Loading the dataset
df = pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
#to get the general info of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
#To find the column names

df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
# To get the count of is_fraud transactions 
# 0 ----> Not fraud, 1 ----> fraud

df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
# To get the count of flagged_fraud transactions

df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
# To check null values in dataset
df.isnull().sum().sum()             # 0 null values in dataset
# Out:
# 0

# %%
# To count the rows and columns

df.shape
# Out:
# (6362620, 11)

# %%
# To find the percentage of fraud transactions

round(df['isFraud'].value_counts()[1]/df.shape[0] * 100,2)
# Out:
# 0.13

# %%
# To find the percentage of Non-Fraud Transactions

round(df['isFraud'].value_counts()[0]/df.shape[0] * 100, 2)
# Out:
# 99.87

# %%
# To plot a horizontal bar graph to check the transaction types

df['type'].value_counts().sort_values().plot(kind="barh", title="Cateogory Wise Transaction counts", color="Orange")
plt.ylabel("Transaction Type")
plt.xlabel("Count")
plt.show()

# %%
df['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
# To plot a bar graph for fraud transactions

fraud_trans_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_trans_type.plot(kind="bar",title="Fraud Transactions", color = "LightGreen")
plt.xlabel("Transaction Type")
plt.ylabel("Fraud Rate")
plt.show()

# %%
df['amount'].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int32

# %%
# To find the distribution of transaction amount in logscale
sns.histplot(np.log1p(df['amount']),bins = 100, kde = True, color = "Green")
plt.title("Transaction Amount Distribution in Log Scale")
plt.xlabel("Log(1 + Amount)")
plt.show()

# %%
#Box plot to show the Amount vs isFraud, filtered under 50k
sns.boxplot(df[df['amount']<50000], x='isFraud', y='amount', color = "Pink")
plt.title("Amount vs isFraud (Filtered under 50k)")
# Out:
# Text(0.5, 1.0, 'Amount vs isFraud (Filtered under 50k)')

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
#Balance chains and anamolies

df['balancedifforg'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['balancediffdest']=df['newbalanceDest'] - df['oldbalanceDest']

# %%
(df['balancedifforg'] < 0).sum()
# Out:
# 1399253

# %%
(df['balancediffdest']<0).sum()
# Out:
# 1238864

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balancedifforg  balancediffdest
# 0         9839.64              0.0
# 1         1864.28              0.0

# %%
frauds_per_step = df[df["isFraud"]==1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values, label="Frauds per step")
plt.xlabel("Step (time)")
plt.ylabel("Number of frauds")
plt.title("Frauds over time")
plt.show()

# %%
df = df.drop(columns="step")

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balancedifforg  balancediffdest
# 0         9839.64              0.0
# 1         1864.28              0.0
# ...

# %%
top_senders = df["nameOrig"].value_counts().head(10)
top_senders
# Out:
# nameOrig
# C1902386530    3
# C363736674     3
# C545315117     3
# C724452879     3
# C1784010646    3
# C1677795071    3
# C1462946854    3
# C1999539787    3
# C2098525306    3
# C400299098     3
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts().head(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df["isFraud"]==1]["nameOrig"].value_counts().head(10)
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C755286039     1
# C973279667     1
# C258213312     1
# C1640703547    1
# C1127265876    1
# C317779855     1
# C1064034527    1
# C1141104763    1
# C1966863341    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER", "CASH_OUT"])]

# %%
fraud_types
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        TRANSFER      181.00  C1305486145         181.00             0.0
# 3        CASH_OUT      181.00   C840083671         181.00             0.0
# 15       CASH_OUT   229133.94   C905080434       15325.00             0.0
# 19       TRANSFER   215310.30  C1670993182         705.00             0.0
# 24       TRANSFER   311685.89  C1984094095       10835.00             0.0
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13             0.0
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28             0.0
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 6362618  TRANSFER   850002.52  C1685995037      850002.52             0.0
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
#Fraud distribution by types
sns.countplot(data= fraud_types, x="type",hue="isFraud")
plt.yscale("log")
plt.title("Fraud Distribution in Transfer and Cashout(Log Scale)")
plt.show()

# %%
df
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0         PAYMENT     9839.64  C1231006815      170136.00       160296.36
# 1         PAYMENT     1864.28  C1666544295       21249.00        19384.72
# 2        TRANSFER      181.00  C1305486145         181.00            0.00
# 3        CASH_OUT      181.00   C840083671         181.00            0.00
# 4         PAYMENT    11668.14  C2048537720       41554.00        29885.86
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13            0.00
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28            0.00
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28            0.00
# 6362618  TRANSFER   850002.52  C1685995037      850002.52            0.00
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52            0.00
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
corr = df[["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "isFraud"]].corr()
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
#Correlation Matrix

sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
#Zero balance after transfer for origin accounts
zero_after_transfer = df[
    (df["oldbalanceDest"]>0) & 
    (df["newbalanceOrig"]==0) & 
    (df["type"]).isin(["TRANSFER", "CASH_OUT"])]
zero_after_transfer
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 3        CASH_OUT      181.00   C840083671         181.00             0.0
# 15       CASH_OUT   229133.94   C905080434       15325.00             0.0
# 19       TRANSFER   215310.30  C1670993182         705.00             0.0
# 24       TRANSFER   311685.89  C1984094095       10835.00             0.0
# 42       CASH_OUT   110414.71   C768216420       26845.41             0.0
# ...           ...         ...          ...            ...             ...
# 6362609  CASH_OUT   258355.42  C1113162093      258355.42             0.0
# 6362611  CASH_OUT    63416.99   C994950684       63416.99             0.0
# 6362613  CASH_OUT  1258818.82  C1436118706     1258818.82             0.0
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
len(zero_after_transfer)
# Out:
# 2170086

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balancedifforg  balancediffdest
# 0         9839.64              0.0
# 1         1864.28              0.0
# ...

# %%
df_model = df.drop(["nameOrig","nameDest","isFlaggedFraud"],axis=1 )
df_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balancedifforg  balancediffdest
# 0             0.0        0         9839.64              0.0
# 1             0.0        0         1864.28              0.0
# 2             0.0        1          181.00              0.0
# 3             0.0        1          181.00         -21182.0
# 4             0.0        0        11668.14              0.0

# %%
categorical = ['type']
numerical = ["amount", "oldbalanceOrg", "newbalanceOrig","oldbalanceDest", "newbalanceDest"]

# %%
X = df_model.drop("isFraud",axis=1)
y = df_model["isFraud"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical),
        ("cat", OneHotEncoder(drop="first"), categorical)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf",LogisticRegression(class_weight="balanced", max_iter=1000))
]
)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.94      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.95      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1802769,  103553],
#        [    136,    2328]], dtype=int64)

# %%
pipeline.score(X_test,y_test) * 100
# Out:
# 94.56780382924016
